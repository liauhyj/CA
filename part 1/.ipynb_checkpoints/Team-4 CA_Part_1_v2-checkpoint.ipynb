# %% [markdown]
# # TEAM 4 CA_PART 1
# # Problem Statement

# %% [markdown]
# In the 21st century,wines are produced across various regions and appreciated from people all over the world.
#
# While overall demand for red wine consumption remains at an all time high, demestic consumption in the wine making countries of France and Italy has observed sharp tapering throughout the last decade. Long focused on the export market, these winemakers are now pushing to increase its domestic sales. However, the domestic market has different taste demands to the export market.To meet its domestic sales targets, winemakers must first understand domestic consumer patterns and achieve customer satisfaction.
#
# ![alt text](Domestic_Consumption_Patterns_1_aoxhio.jpg "Title")
#
# Critical research into the attributes that shape the taste character of wine has been done, with data reflected in the following dataset. This report aims to identify the relationships that intertwines wine attributes to its quality, transforming  customer feedback into measurable indicators in the wine production process.
#
# The following classification models will be used, while also utilising feature engineering techniques to highlight key attributes with the most influence on outcome.
#
# 1.Logistic Regression Model
#
# 2.K-NN Model
#
# 3.Decision Tree Model
#
# The independent variables of red wine in relation to is quality will be explored.These variables are:
#
# 1 - fixed acidity (tartaric acid - g / dm^3) - most acids involved with wine or fixed or nonvolatile
#
# 2 - volatile acidity (acetic acid - g / dm^3) - the amount of acetic acid in wine, which at too high of levels can lead to an       unpleasant, vinegar taste
#
# 3 - citric acid (g / dm^3) - found in small quantities, citric acid can add 'freshness' and flavor to wines
#
# 4 - residual sugar (g / dm^3) - the amount of sugar remaining after fermentation stops, it's rare to find wines with less than 1     gram/liter and wines with greater than 45 grams/liter are considered sweet
#
# 5 - chlorides (sodium chloride - g / dm^3) - the amount of salt in the wine
#
# 6 - free sulfur dioxide (mg / dm^3) - the free form of SO2 exists in equilibrium between molecular SO2 (as a dissolved gas) and     bisulfite ion; it prevents microbial growth and the oxidation of wine
#
# 7 - total sulfur dioxide (mg / dm^3) - ,the amount of free and bound forms of S02; in low concentrations, SO2 is mostly undetectable     in wine, but at free SO2 concentrations over 50 ppm, SO2 becomes evident in the nose and taste of wine
#
# 8 - density (g / cm^3) - the density of water is close to that of water depending on the percent alcohol and sugar content
#
# 9 - pH - describes how acidic or basic a wine is on a scale from 0 (very acidic) to 14 (very basic); most wines are between 3-4     on the pH scale
#
# 10 - sulphates (potassium sulphate - g / dm3) - a wine additive which can contribute to sulfur dioxide gas (S02) levels, wich        acts as an antimicrobial and antioxidant
#
# 11 - alcohol (% by volume) - the percent alcohol content of the wine
#
# The dependent variable will stand as:
# 1 - quality (score between 0 and 10) - based on sensory data
#
#
#
# The source of the original dataset is from: https://www.kaggle.com/danielpanizzo/wine-quality

# %% [markdown]
# # Import all required libraries

# %%
# Import the modules required to process this project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import graphviz
import sklearn
import seaborn as sb
import seaborn as sns
from time import time # to know processing time
from sklearn.linear_model import LogisticRegression 
from sklearn.model_selection import train_test_split # to split  data
from sklearn.metrics import accuracy_score # to use in checking accuracy
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
from graphviz import Source

# %% [markdown]
# # Read Dataset

# %%
# Read the csv data file
df = pd.read_csv('wine quality - red.csv')
#show the independent and dependent variables in table form
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %% [markdown]
# # Data Processing

# %%
# First, we print the shape of the data file in (rows,columns)
print(df.shape)
# Out:
# (1599, 12)

# %%
# Using the inplace = True command, we compare and observe that the shape remains the same as before.
# Hence, there are no null values
df.dropna(inplace = True)
print(df.shape)
# Out:
# (1599, 12)

# %%
# check if the categories are balanced
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# # Splitting into Training and Test sets

# %%
x = df.iloc[:,:-1] #reading the features without labels
y = df.iloc[:,-1] # reading the 

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 0)
x_train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 140             8.4             0.745         0.11             1.9      0.090
# 1232            7.6             0.430         0.29             2.1      0.075
# 720             8.4             0.560         0.04             2.0      0.082
# 77              6.8             0.785         0.00             2.4      0.104
# 39              7.3             0.450         0.36             5.9      0.074
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 140                  16.0                  63.0  0.99650  3.19       0.82
# 1232                 19.0                  66.0  0.99718  3.40       0.64
# 720                  10.0                  22.0  0.99760  3.22       0.44
# 77                   14.0                  30.0  0.99660  3.52       0.55
# 39                   12.0                  87.0  0.99780  3.33       0.83
#
#       alcohol
# 140       9.6
# 1232      9.5
# 720       9.6
# 77       10.7
# 39       10.5

# %% [markdown]
# # Logistic Regression without Feature Selection (Acc: 0.62)

# %%
import time

logReg = LogisticRegression (solver = 'lbfgs', multi_class = 'auto', random_state = 0, max_iter = 8000) 

start = time.time()
logReg.fit(x_train, y_train)
end = time.time()
delta=end-start
print('In Logistic Regression, Training model takes %s seconds.'%delta)
# Out:
# In Logistic Regression, Training model takes 3.293466329574585 seconds.

# %% [markdown]
# Calculate the duration of prediction and the accuracy of LR Model

# %%
start = time.time()
y_pred = logReg.predict(x_test)
end = time.time() 
delta_train=end-start
print('In Logistic Regression, Prediction takes %s seconds.'%delta_train)
print('In Logistic Regression, Accuracy score: %s' %accuracy_score(y_test, y_pred))
# Out:
# In Logistic Regression, Prediction takes 0.0 seconds.
# In Logistic Regression, Accuracy score: 0.62

# %% [markdown]
# Get the Model's confusion matrix

# %%
confusion_matrix (y_test, y_pred)
# Out:
# array([[  0,   0,   2,   0,   0,   0],
#        [  0,   0,   9,   5,   0,   0],
#        [  0,   0, 129,  39,   1,   0],
#        [  0,   0,  52, 108,  10,   0],
#        [  0,   0,   3,  26,  11,   0],
#        [  0,   0,   0,   3,   2,   0]], dtype=int64)

# %% [markdown]
# # K-NN Classification without Feature Selection (Acc: 0.5475)

# %%
k_array=np.arange(3,21,2) # set the various k values
k_array
# Out:
# array([ 3,  5,  7,  9, 11, 13, 15, 17, 19])

# %%
k_max = 0
ac_max = 0
for k in k_array:
    knn_ex = KNeighborsClassifier(n_neighbors=k)
    knn_ex.fit(x_train,y_train)
    ac = accuracy_score(y_test,knn_ex.predict(x_test))
    time_diffKNN = end_timeKNN - start_timeKNN
    if (ac > ac_max):
        k_max = k
        ac_max = ac
    print("K =", k, "and accuracy =", ac)
print("----------")
print("The number of neighbours with the best accuracy for KNN is", k_max, "of accuracy", ac_max)
# Out:
# K = 3 and accuracy = 0.48
# K = 5 and accuracy = 0.47
# K = 7 and accuracy = 0.5025
# K = 9 and accuracy = 0.4925
# K = 11 and accuracy = 0.5225
# K = 13 and accuracy = 0.51
# K = 15 and accuracy = 0.5225
# K = 17 and accuracy = 0.53
# K = 19 and accuracy = 0.5475
# ----------
# The number of neighbours with the best accuracy for KNN is 19 of accuracy 0.5475

# %%
#time to model KNN with 19 neighbours
import time

start_time = time.time()
knn_1=KNeighborsClassifier(n_neighbors=19)
knn_1.fit(x_train,y_train)

time_taken = time.time() - start_time

print("The time taken is", time_taken,)
# Out:
# The time taken is 0.015569686889648438

# %%
#time to perform KNN prediction of entire dataset with model
start_time = time.time()
y_predKNN = knn_1.predict(x_test)
time_taken = time.time() - start_time

print("The time taken is", time_taken,)
print("The prediction accuracy is", accuracy_score(y_test,y_predKNN))
print("The F1 value is", f1_score(y_test, y_predKNN, average = 'micro'))
# Out:
# The time taken is 0.03347015380859375
# The prediction accuracy is 0.5475
# The F1 value is 0.5475

# %%
#time to perform KNN prediction of a single outcome
start_time = time.time()

knn_1.predict([(8.4,0.430,0.36,5.9,0.074,14.0,63.0,0.99650,3.19,0.82,9.6)])

end_time = time.time()
time_taken = end_time - start_time

print("The time taken is", time_taken,)
# Out:
# The time taken is 0.015573740005493164

# %%
confusion_matrix(y_test, y_predKNN)
# Out:
# array([[  0,   0,   1,   1,   0,   0],
#        [  0,   0,  14,   0,   0,   0],
#        [  0,   0, 119,  48,   2,   0],
#        [  0,   0,  72,  93,   5,   0],
#        [  0,   0,   6,  27,   7,   0],
#        [  0,   0,   1,   2,   2,   0]], dtype=int64)

# %% [markdown]
# # Decision Trees without Feature Selection (Acc: 0.6325)

# %%
# train the model and time taken
import time

dt = DecisionTreeClassifier(random_state = 0)

training_start_time = time.time()
dt.fit(x_train, y_train)
training_time_DT = time.time() - training_start_time

print("Duration of training in Decision Tree")
print("--- %s seconds ---" % (training_time_DT))
# Out:
# Duration of training in Decision Tree
# --- 0.022228240966796875 seconds ---

# %%
#accuracy of decision tree prediction
accuracy = accuracy_score(y_test, dt.predict(x_test))
print(accuracy)
# Out:
# 0.6325

# %%
# validate the model using the test dataset
# time taken to predict results from x_test to be used to compare against y_test

predict_start_time = time.time()
y_predDT = dt.predict(x_test)
predict_time_taken = time.time() - predict_start_time

print("Duration of prediction")
print("--- %s seconds ---" % (predict_time_taken))
# Out:
# Duration of prediction
# --- 0.0 seconds ---

# %%
# time taken to predict single result
predict_start_time = time.time()
single_result = dt.predict([[8.0, 0.695, 0.58, 2.1, 0.191, 21.0, 45.0, 0.875, 4.32, 1.12, 11.0]])
predict_time_taken = time.time() - predict_start_time
print("Predicted label:", single_result)
print("Time taken:", predict_time_taken)
# Out:
# Predicted label: [8]
# Time taken: 0.0

# %%
# confusion matrix of the model

confusion_matrix(y_test, y_predDT)
# Out:
# array([[  0,   0,   1,   1,   0,   0],
#        [  0,   2,   7,   3,   2,   0],
#        [  1,  10, 115,  30,  12,   1],
#        [  0,   3,  37, 111,  17,   2],
#        [  0,   1,   3,  10,  24,   2],
#        [  0,   0,   0,   2,   2,   1]], dtype=int64)

# %%
# display the tree, with no output file

Source(tree.export_graphviz(dt, out_file=None, class_names=["3", "4", "5", "6", "7", "8"], 
                            feature_names= x_train.columns))

# %% [markdown]
# # Feature Engineering via Feature Selection

# %% [markdown]
# In this section, we will reduce the number of features in the model using feature selection. We only want to keep independent variables that are sufficiently correlated with the dependent variable and also make sure that the independent variables in the model are not strongly correlated with each other.

# %% [markdown]
# # Correlation Matrix

# %% [markdown]
# First, we look at the correlation matrix of the original dataset.

# %%
corr_mat = df.corr()

# plot the heatmap of the correlation matrix
plt.figure(figsize=(13,9))
ax = sns.heatmap(data=corr_mat, annot=True, annot_kws={"weight": "bold"})
plt.title("Correlation Matrix for wine dataset")
plt.show()

# %% [markdown]
# # Filter candiate features by checking their correlation with respect to the dependent variable

# %% [markdown]
# Our potential candidates for features in our model are features that have an absolute value of correlation > 0.3 with respect to the dependent variable, quality. We will now take a look at these candidates.

# %%
# focus on column of the corr matrix that shows correlation w.r.t dep variable
target_label = "quality"
target_column = corr_mat[target_label]

# drop the row of the target_column which shows the correlation of the dep variable w.r.t itself
target_column.drop([target_label], inplace=True)

# define lower bound of the correlation of indep variable w.r.t dep variable
corr_y_lower_bound = 0.3

# filter candidate features using the defined lower bound
candidate_features = target_column[abs(target_column) > corr_y_lower_bound]
print("Features that have |corr| > %s with %s:\n%s\n" % (corr_y_lower_bound, target_label, candidate_features))
# Out:
# Features that have |corr| > 0.3 with quality:
# volatile acidity   -0.390558
# alcohol             0.476166
# Name: quality, dtype: float64

# %% [markdown]
# # Filter candidate features by checking their correlation with respect to each other

# %% [markdown]
# After filtering out the potential candidates using the lower bound of 0.3, we are left with 2 candidates, namely, volatile acidity and alcohol. Now, we check if these features are strongly correlated with each other, if they are, we keep the one which has the highest correlation with the dependent variable, quality, and remove the others.

# %%
labels_to_drop = list(set(corr_mat.index) - set(candidate_features.index))

# drop columns and indexes that are not candidate features
new_corr_mat = corr_mat.drop(index=labels_to_drop, columns=labels_to_drop)

print("%s\n" % new_corr_mat)

skip = []
selected = []

print("%s\n" % list(new_corr_mat.columns))

# define lower bound of the correlation of dep variable w.r.t to dep variable
corr_x_lower_bound = 0.3
counter = 1

for col in list(new_corr_mat.columns):
    if not (col in skip or col in selected):
        print("---------------------Pass %s---------------------\n" % counter)
        
        #we find the features / X which are highly correlated to each other
        temp = new_corr_mat[col]
        temp = temp[abs(temp) > corr_x_lower_bound]
        print("Features that have |corr| > %s with %s:\n%s\n" % (corr_x_lower_bound, col, temp))
        
        #then we select one from amongst them that has the highest correlation to Y as their representative
        corr_wrt_y_for_strongly_corr_features = candidate_features[temp.index]
        print("Correlation wrt to y for features that have |corr| > %s with %s:\n%s\n" %
              (corr_x_lower_bound, col, corr_wrt_y_for_strongly_corr_features))
        max_corr_with_y_feature = corr_wrt_y_for_strongly_corr_features.abs().idxmax()
        print("Feature that is most correlated with y:\n%s\n" % max_corr_with_y_feature)
        selected.append(max_corr_with_y_feature)
        print("Current selected features = %s\n" % selected)
        
        #we skip over the other features since we already have a representative for them
        skip.extend(list(set(corr_wrt_y_for_strongly_corr_features.index) - set([max_corr_with_y_feature])))
        print("Current features to skip = %s\n" % skip)
        counter = counter + 1
# Out:
#                   volatile acidity   alcohol
# volatile acidity          1.000000 -0.202288
# alcohol                  -0.202288  1.000000
#
# ['volatile acidity', 'alcohol']
#
# ---------------------Pass 1---------------------
#
# Features that have |corr| > 0.3 with volatile acidity:
# volatile acidity    1.0
# Name: volatile acidity, dtype: float64
#
# Correlation wrt to y for features that have |corr| > 0.3 with volatile acidity:
# volatile acidity   -0.390558
# Name: quality, dtype: float64
#
# Feature that is most correlated with y:
# volatile acidity
#
# Current selected features = ['volatile acidity']
#
# Current features to skip = []
#
# ---------------------Pass 2---------------------
#
# Features that have |corr| > 0.3 with alcohol:
# alcohol    1.0
# Name: alcohol, dtype: float64
#
# Correlation wrt to y for features that have |corr| > 0.3 with alcohol:
# alcohol    0.476166
# Name: quality, dtype: float64
#
# Feature that is most correlated with y:
# alcohol
#
# Current selected features = ['volatile acidity', 'alcohol']
#
# Current features to skip = []

# %% [markdown]
# # Features used in our model

# %% [markdown]
# As seen from the output of the preceding cell, the candidate features do not have an absolute value of correlation of > 0.3 with respect to each other. Hence, the features we will be using in our model are the following features:

# %%
x_selected = df[selected]

x_selected
# Out:
#       volatile acidity  alcohol
# 0                0.700      9.4
# 1                0.880      9.8
# 2                0.760      9.8
# 3                0.280      9.8
# 4                0.700      9.4
# ...                ...      ...
# 1594             0.600     10.5
# 1595             0.550     11.2
# 1596             0.510     11.0
# 1597             0.645     10.2
# 1598             0.310     11.0
#
# [1599 rows x 2 columns]

# %%
y_selected = df["quality"] # can remove this after combining

y_selected
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %% [markdown]
# # Visualising the data for 2 features

# %% [markdown]
# As we are only using 2 features in our new model, we are now able to visualise the data of the dependent variables in the form of a scatter plot

# %%
# plot the scatter plot

plt.figure(figsize=(14, 8), dpi=80)

for quality in np.unique(y_selected):
    x_by_quality = x_selected.values[y_selected == quality]
    plt.scatter(x=x_by_quality[:, 0], 
                y=x_by_quality[:, 1],
                label="Quality = " + str(quality))

plt.legend()
plt.title('Scatter plot of volatile acidity vs alcohol')
plt.xlabel(x_selected.columns[0])
plt.ylabel(x_selected.columns[1])
plt.show()

# %% [markdown]
# # AFTER Feature Engineering

# %% [markdown]
# # Splitting the dataset into training and test once again

# %%
logReg2 = LogisticRegression (solver = 'lbfgs', multi_class = 'auto', random_state = 0, max_iter = 8000) # use the same seed for random_state

# use the same seed for random_state 

x2 = x_selected
y2 = y_selected

x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y2, random_state = 0)

x2_train.head()
# Out:
#       volatile acidity  alcohol
# 140              0.745      9.6
# 1232             0.430      9.5
# 720              0.560      9.6
# 77               0.785     10.7
# 39               0.450     10.5

# %% [markdown]
# # Logistic Regression with Optimal Model (Acc: 0.59)

# %%
start_LR = time.time()
logReg2.fit(x2_train, y2_train)
end_LR = time.time()
delta_LR=end_LR-start_LR
print('The optimal training model in Logistic Regression takes %s seconds.'%delta_LR)
# Out:
# The optimal training model in Logistic Regression takes 0.16283845901489258 seconds.

# %% [markdown]
# Calculate the duration of prediction and the accuracy of the optimal LR Model

# %%
start = time.time()
y2_pred = logReg2.predict(x2_test)
end = time.time()
 
delta=end-start
print('The optimal LR model prediction takes %s seconds.'%delta)
print('The optimal LR model accuracy score: %s' %accuracy_score(y2_test, y2_pred))
# Out:
# The optimal LR model prediction takes 0.0 seconds.
# The optimal LR model accuracy score: 0.59

# %% [markdown]
# Get the optimal model's confusion matrix

# %%
confusion_matrix (y2_test, y2_pred)
# Out:
# array([[  0,   0,   2,   0,   0,   0],
#        [  0,   0,  10,   3,   1,   0],
#        [  0,   0, 129,  39,   1,   0],
#        [  0,   0,  61,  98,  11,   0],
#        [  0,   0,   3,  28,   9,   0],
#        [  0,   0,   0,   4,   1,   0]], dtype=int64)

# %% [markdown]
# # KNN Classification with Optimal Model (Acc: 0.5775)

# %%
k_max = 0
ac_max = 0
k_array = np.arange(3, 20, 2)
for k in k_array:
   
    knn_ex = KNeighborsClassifier(n_neighbors = k)
    knn_ex.fit(x2_train, y2_train)
    Y_pred = knn_ex.predict(x2_test)
    ac = accuracy_score(y2_test, Y_pred)
    print("K:", k, "Accuracy:",ac)
    if (ac != 1) and (ac > ac_max):
        ac_max = ac
        k_max = k
print("--------------")
print("K max: ", k_max)
print("Accuracy max: ", ac_max)

print("Time elapsed in training for 9 various K values: ", time_diff)
# Out:
# K: 3 Accuracy: 0.5375
# K: 5 Accuracy: 0.56
# K: 7 Accuracy: 0.5775
# K: 9 Accuracy: 0.55
# K: 11 Accuracy: 0.55
# K: 13 Accuracy: 0.535
# K: 15 Accuracy: 0.56
# K: 17 Accuracy: 0.5575
# K: 19 Accuracy: 0.575
# --------------
# K max:  7
# Accuracy max:  0.5775
# Time elapsed in training for 9 various K values:  0.14690899848937988

# %%
#Time to train the model with K =  7 & F1 score
import time
start_time = time.time()
knn = KNeighborsClassifier(n_neighbors = 7)
knn.fit(x2_train, y2_train)
print("Time taken is", (time.time() - start_time))
Y_pred = knn.predict(x2_test)
print("F1 score: ", f1_score(y2_test, y_pred, average = 'micro'))
print("Accuracy: ", accuracy_score(y2_test, Y_pred))
# Out:
# Time taken is 0.0
# F1 score:  0.545
# Accuracy:  0.5775

# %%
#Time to predict a single outcome with model K=7
import time
start_time = time.time()
abc = np.array([0.1, 0.3, 0.2, 0.2]).reshape(2,2)
Y_prediction = knn.predict(abc)
print(Y_prediction)
print("Time taken is", (time.time() - start_time))
# Out:
# [6 6]
# Time taken is 0.0

# %% [markdown]
# # Decision Tree with Optimal Model (Acc: 0.545)

# %%
# instantiate a decision tree model. All parameters can be omited to use default ones.
# details please check https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
dt = DecisionTreeClassifier() 
dt.fit(x2_train, y2_train) # train our model
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#Time taken to predict outcome based on model
import time
start_time = time.time()
y_pred = dt.predict(x2_test) # let the model predict the test data
print("Time taken is", (time.time() - start_time))
# Out:
# Time taken is 0.0

# %%
# get the new accuracy score of the new dt model
import time
start_time = time.time()
print("Accuracy:", accuracy_score(y2_test, y_pred))
print("Time taken is", (time.time() - start_time))
# Out:
# Accuracy: 0.545
# Time taken is 0.015624523162841797

# %% [markdown]
# # Visualising the new DT model

# %%
# show the decision tree model

Source(tree.export_graphviz(dt, out_file=None, class_names=True, feature_names= x_trainDT.columns)) # display the tree, with no output file
